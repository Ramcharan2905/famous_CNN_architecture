# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
def SEBlock(input_tensor, reduction=16):
    channels = input_tensor.shape[-1]

    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Dense(channels // reduction, activation='relu')(se)
    se = layers.Dense(channels, activation='sigmoid')(se)
    se = layers.Reshape((1, 1, channels))(se)

    return layers.Multiply()([input_tensor, se])

# %%
def SENet(input_shape=(32, 32, 3), num_classes=10):
    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(inputs)
    x = SEBlock(x)
    x = layers.MaxPooling2D((2,2))(x)

    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
    x = SEBlock(x)
    x = layers.MaxPooling2D((2,2))(x)

    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
    x = SEBlock(x)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# %%
# Load and preprocess data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
model = SENet(input_shape=(32, 32, 3), num_classes=10)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5,  validation_split=0.1)
# Out:
# Epoch 1/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.2460 - loss: 1.9709 - val_accuracy: 0.4258 - val_loss: 1.5272
# Epoch 2/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4336 - loss: 1.5210 - val_accuracy: 0.5074 - val_loss: 1.3400
# Epoch 3/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5174 - loss: 1.3147 - val_accuracy: 0.5626 - val_loss: 1.1850
# Epoch 4/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5717 - loss: 1.1755 - val_accuracy: 0.5986 - val_loss: 1.1169
# Epoch 5/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6123 - loss: 1.0791 - val_accuracy: 0.6164 - val_loss: 1.0721

# %%
model.fit(X_train, y_train, epochs=5,  validation_split=0.1)
# Out:
# Epoch 1/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6489 - loss: 0.9783 - val_accuracy: 0.6598 - val_loss: 0.9428
# Epoch 2/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6756 - loss: 0.9054 - val_accuracy: 0.6778 - val_loss: 0.8953
# Epoch 3/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7004 - loss: 0.8466 - val_accuracy: 0.6770 - val_loss: 0.9166
# Epoch 4/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7173 - loss: 0.7916 - val_accuracy: 0.7102 - val_loss: 0.8206
# Epoch 5/5
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7370 - loss: 0.7372 - val_accuracy: 0.7320 - val_loss: 0.7662

# %%
model.fit(X_train, y_train, epochs=10,  validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7492 - loss: 0.7042 - val_accuracy: 0.7338 - val_loss: 0.7632
# Epoch 2/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7725 - loss: 0.6467 - val_accuracy: 0.7452 - val_loss: 0.7249
# Epoch 3/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7877 - loss: 0.6000 - val_accuracy: 0.7664 - val_loss: 0.6821
# Epoch 4/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7996 - loss: 0.5574 - val_accuracy: 0.7514 - val_loss: 0.7086
# Epoch 5/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8118 - loss: 0.5363 - val_accuracy: 0.7706 - val_loss: 0.6735
# Epoch 6/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8316 - loss: 0.4899 - val_accuracy: 0.7642 - val_loss: 0.7123
# Epoch 7/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8384 - loss: 0.4594 - val_accuracy: 0.7746 - val_loss: 0.6808
# Epoch 8/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8501 - loss: 0.4244 - val_accuracy: 0.7636 - val_loss: 0.6953
# Epoch 9/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8587 - loss: 0.4038 - val_accuracy: 0.7856 - val_loss: 0.6560
# Epoch 10/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8733 - loss: 0.3630 - val_accuracy: 0.7898 - val_loss: 0.6585

# %%
model.fit(X_train, y_train, epochs=10,  validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8807 - loss: 0.3426 - val_accuracy: 0.7870 - val_loss: 0.6918
# Epoch 2/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8902 - loss: 0.3114 - val_accuracy: 0.7890 - val_loss: 0.6993
# Epoch 3/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8985 - loss: 0.2845 - val_accuracy: 0.7822 - val_loss: 0.7214
# Epoch 4/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9071 - loss: 0.2672 - val_accuracy: 0.7832 - val_loss: 0.7688
# Epoch 5/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9142 - loss: 0.2446 - val_accuracy: 0.7794 - val_loss: 0.7908
# Epoch 6/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9208 - loss: 0.2240 - val_accuracy: 0.7776 - val_loss: 0.7665
# Epoch 7/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9290 - loss: 0.2026 - val_accuracy: 0.7876 - val_loss: 0.8019
# Epoch 8/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9369 - loss: 0.1750 - val_accuracy: 0.7844 - val_loss: 0.8599
# Epoch 9/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9397 - loss: 0.1724 - val_accuracy: 0.7920 - val_loss: 0.8811
# Epoch 10/10
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9454 - loss: 0.1544 - val_accuracy: 0.7848 - val_loss: 0.9076

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7708 - loss: 0.9678
# [0.9503479599952698, 0.7720999717712402]
