# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def LeNet5(input_shape=(32, 32, 1), num_classes=10):
    model = models.Sequential()
    
    model.add(layers.Conv2D(6, kernel_size=5, activation='tanh', input_shape=input_shape))
    model.add(layers.AveragePooling2D(pool_size=(2, 2)))
    
    model.add(layers.Conv2D(16, kernel_size=5, activation='tanh'))
    model.add(layers.AveragePooling2D(pool_size=(2, 2)))
    
    model.add(layers.Flatten())
    
    model.add(layers.Dense(84, activation='tanh'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    
    return model

# %%
# load data
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
# preprocess data
from tensorflow.keras.utils import to_categorical

X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Build, compile and train a model

model = LeNet5(input_shape=(32, 32, 3), num_classes=10)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=30, batch_size=128, validation_split=0.1)
# Out:
# C:\Users\ramch\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.2838 - loss: 1.9826 - val_accuracy: 0.3752 - val_loss: 1.7584
# Epoch 2/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.3957 - loss: 1.7254 - val_accuracy: 0.4130 - val_loss: 1.6645
# Epoch 3/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.4227 - loss: 1.6421 - val_accuracy: 0.4390 - val_loss: 1.5839
# Epoch 4/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.4616 - loss: 1.5313 - val_accuracy: 0.4638 - val_loss: 1.5218
# Epoch 5/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.4805 - loss: 1.4786 - val_accuracy: 0.4758 - val_loss: 1.4655
# Epoch 6/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5009 - loss: 1.4123 - val_accuracy: 0.5000 - val_loss: 1.4247
# Epoch 7/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5131 - loss: 1.3747 - val_accuracy: 0.5106 - val_loss: 1.3924
# Epoch 8/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5304 - loss: 1.3274 - val_accuracy: 0.5202 - val_loss: 1.3634
# Epoch 9/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5427 - loss: 1.2929 - val_accuracy: 0.5164 - val_loss: 1.3636
# Epoch 10/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5530 - loss: 1.2651 - val_accuracy: 0.5388 - val_loss: 1.3206
# Epoch 11/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.5639 - loss: 1.2429 - val_accuracy: 0.5300 - val_loss: 1.3337
# Epoch 12/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.5700 - loss: 1.2212 - val_accuracy: 0.5402 - val_loss: 1.3018
# Epoch 13/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.5765 - loss: 1.2045 - val_accuracy: 0.5358 - val_loss: 1.3156
# Epoch 14/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.5809 - loss: 1.1882 - val_accuracy: 0.5428 - val_loss: 1.2957
# Epoch 15/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5914 - loss: 1.1623 - val_accuracy: 0.5452 - val_loss: 1.2815
# Epoch 16/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5947 - loss: 1.1564 - val_accuracy: 0.5520 - val_loss: 1.2890
# Epoch 17/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6021 - loss: 1.1318 - val_accuracy: 0.5348 - val_loss: 1.3052
# Epoch 18/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6032 - loss: 1.1288 - val_accuracy: 0.5460 - val_loss: 1.2930
# Epoch 19/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6113 - loss: 1.1145 - val_accuracy: 0.5534 - val_loss: 1.2706
# Epoch 20/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.6118 - loss: 1.0997 - val_accuracy: 0.5548 - val_loss: 1.2790
# Epoch 21/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6150 - loss: 1.0948 - val_accuracy: 0.5564 - val_loss: 1.2646
# Epoch 22/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6273 - loss: 1.0728 - val_accuracy: 0.5468 - val_loss: 1.2880
# Epoch 23/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6309 - loss: 1.0566 - val_accuracy: 0.5570 - val_loss: 1.2753
# Epoch 24/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.6379 - loss: 1.0398 - val_accuracy: 0.5542 - val_loss: 1.2774
# Epoch 25/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6420 - loss: 1.0286 - val_accuracy: 0.5512 - val_loss: 1.3020
# Epoch 26/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6400 - loss: 1.0273 - val_accuracy: 0.5528 - val_loss: 1.2805
# Epoch 27/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6442 - loss: 1.0182 - val_accuracy: 0.5554 - val_loss: 1.2801
# Epoch 28/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.6465 - loss: 1.0090 - val_accuracy: 0.5506 - val_loss: 1.2856
# Epoch 29/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6543 - loss: 0.9878 - val_accuracy: 0.5556 - val_loss: 1.2763
# Epoch 30/30
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6538 - loss: 0.9880 - val_accuracy: 0.5606 - val_loss: 1.2787

# %%
# Evaluate

test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5559 - loss: 1.2806
